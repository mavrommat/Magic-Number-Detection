# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
from scipy.stats import gaussian_kde
from pprint import pprint
from scipy.integrate import simpson
from collections import Counter
import logging
logging.basicConfig(level=logging.DEBUG)

from get_magic_numbers import get_magic_numbers_main

from string_magic_numbers import magic_strings_detection as string_values_process
from sign_violation_magic_numbers import sign_violation_magic_numbers as opposite_sign_process
from distance_based_magic_numbers import delta_distributed_magic_numbers 
from identical_magic_numbers import identical_column_magic_numbers as all_values_are_same
from magic_dictionaries import magic_dictionary, add_to_master_dict, safe_concatenate
from magic_dictionaries import clean_magic_results
from density_plot import plot_data_density

# %%
def synthetic_data(
        mean, 
        sigma, 
        num_samples=1000, 
        random_seed=None, 
        magic_values=[-999, 999],
        quantities=[100, 50], 
        col_names="synthetic_col"):

    if random_seed is not None:
        np.random.seed(random_seed)

    # Calculate Clipping Bounds (HARDCODED 3-SIGMA) ---
    # Hardcode sigma_limit = 3.0 to maintain the 99.7% for testing consistency
    SIGMA_LIMIT = 3.0  
    lower_bound = mean - SIGMA_LIMIT * sigma
    upper_bound = mean + SIGMA_LIMIT * sigma
    
    # Generate and Clip the Main Normal Distribution Samples 
    
    # Generate the initial samples
    synthetic_col = np.random.normal(mean, sigma, num_samples)
    
    # Apply 3-sigma clipping to ensure the normal data is within the 99.7% range
    synthetic_col = np.clip(synthetic_col, a_min=lower_bound, a_max=upper_bound)

    # --- 3. Add Magic Values (Original behavior: total size increases) ---

    if len(magic_values) != len(quantities):
        raise ValueError("Length of magic_values must match length of quantities")
    
    # If no magic values returns the normal distribution
    if len(magic_values) == 0:
        df = pd.DataFrame({col_names: synthetic_col})
        return df
    
    # Add magic values to the dataset
    for magic_value, quantity in zip(magic_values, quantities):
        magic_samples = np.full(quantity, magic_value)
        synthetic_col = np.concatenate((synthetic_col, magic_samples))
    
    # Shuffle the final array
    np.random.shuffle(synthetic_col)
    
    df = pd.DataFrame({col_names: synthetic_col})
    return df

# Note: If you use the parameters quantities=[100, 50] and num_samples=1000,
# the final dataset will have 1000 + 100 + 50 = 1150 samples.

# %%
def generate_randomized_df(n_columns, num_samples=1000):

    column_list = []
    
    for i in range(n_columns):
        random_mean = np.random.uniform(10, 500)    # Mean between 10 and 500
        random_sigma = np.random.uniform(1, 50)     # Sigma between 1 and 50
        
        df_col = synthetic_data(
            mean=random_mean, 
            sigma=random_sigma, 
            num_samples=num_samples, 
            col_names=i, # Sets the header to 0, 1,... n-1
            random_seed=np.random.randint(0, 100000) # Different seed for each column
        )
        column_list.append(df_col)
    
    # 3. Combine all columns into one DataFrame
    final_df = pd.concat(column_list, axis=1)
    
    return final_df

df_final = generate_randomized_df(n_columns=5, num_samples=1000)

# p is the value you want, k is naturally the number of rows in the df
p = 42 
df_final[len(df_final.columns)] = p

for times in range(10):
    random_row_index = np.random.randint(0, len(df_final))
    df_final.loc[random_row_index, 4] = "Flag"
print(df_final.describe())
# Out:
#                  0            1            2            3       5
# count  1150.000000  1150.000000  1150.000000  1150.000000  1150.0
# mean    164.506201    10.631472   -30.163483   -24.857665    42.0
# std     391.248395   366.750728   362.045719   360.947495     0.0
# min    -999.000000  -999.000000  -999.000000  -999.000000    42.0
# 25%     229.485052    32.934930   -19.897151     7.552043    42.0
# 50%     238.394178    60.729368    11.288236    20.844876    42.0
# 75%     247.467948    86.149190    44.404596    33.006552    42.0
# max     999.000000   999.000000   999.000000   999.000000    42.0
# C:\Users\mixal\AppData\Local\Temp\ipykernel_10556\3057800188.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Flag' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_final.loc[random_row_index, 4] = "Flag"

# %%
rows, columns = df_final.shape

extended_col_info =[]
for i in range(columns):
    column_info = []

    column_info.append(i)  # Column name/index
    column_info.append("N") # Indicate Numerical column
    column_info.append(rows)  # Number of rows
    extended_col_info.append(column_info)

# %%
magic_master_dict, magic_cleaned_dict = get_magic_numbers_main(df_final, extended_col_info, sign_violation_theshold = 3,gauss_threshold = 0.01, overlap_threshold=5.0, plot_graphs = False)
# Out:
#   Skipping Processes 2 and 3 due to identical numeric values.

# %%
print ("Detected Magic Numbers:")
pprint(magic_master_dict)
# Out:
# Detected Magic Numbers:
# {0: {'all_magic_numbers': None,
#      'magic_distanced_numbers': array([ 999., -999.]),
#      'magic_sign_violation': [-999.0],
#      'magic_strings': []},
#  1: {'all_magic_numbers': None,
#      'magic_distanced_numbers': array([ 999., -999.]),
#      'magic_sign_violation': [],
#      'magic_strings': []},
#  2: {'all_magic_numbers': None,
#      'magic_distanced_numbers': array([ 999., -999.]),
#      'magic_sign_violation': [],
#      'magic_strings': []},
#  3: {'all_magic_numbers': None,
#      'magic_distanced_numbers': array([ 999., -999.]),
#      'magic_sign_violation': [],
#      'magic_strings': []},
#  4: {'all_magic_numbers': None,
#      'magic_distanced_numbers': array([ 999., -999.]),
#      'magic_sign_violation': [-999.0],
#      'magic_strings': ['Flag']},
#  5: {'all_magic_numbers': 42,
#      'magic_distanced_numbers': [],
#      'magic_sign_violation': [],
#      'magic_strings': []}}

# %%
pprint ("Cleaned Magic Numbers:")
pprint(magic_cleaned_dict)
# Out:
# 'Cleaned Magic Numbers:'
# {0: [-999.0, 999.0],
#  1: [-999.0, 999.0],
#  2: [-999.0, 999.0],
#  3: [-999.0, 999.0],
#  4: ['-999.0', '999.0', 'Flag']}

# %%
from astropy.io import ascii

readme_url = "https://cdsarc.cds.unistra.fr/ftp/J/A+A/469/861/ReadMe"
data_url = "https://cdsarc.cds.unistra.fr/ftp/J/A+A/469/861/table1.dat"

table = ascii.read(data_url, readme=readme_url, format="cds")
df = table.to_pandas()
print(df[:9])
# Out:
#    [BBG2007b] n_[BBG2007b]              Name  RAh  RAm    RAs DE-  DEd  DEm  \
# 0           1          NaN  J005535.4+261752    0   55  35.44   +   26   17
# 1           2          NaN  J005536.0+262711    0   55  36.06   +   26   27
# 2           3          NaN  J005539.1+261457    0   55  39.16   +   26   14
# 3           4          NaN  J005539.4+261531    0   55  39.45   +   26   15
# 4           5          NaN  J005540.1+262056    0   55  40.13   +   26   20
# 5           6          NaN  J005544.5+261318    0   55  44.52   +   26   13
# 6           7          NaN  J005544.5+262755    0   55  44.54   +   26   27
# 7           8            F  J005544.5+262819    0   55  44.56   +   26   28
# 8           9          NaN  J005544.8+262627    0   55  44.86   +   26   26
#
#     DEs   Bmag   Rmag     RV  e_RV SpClass
# 0  52.8  21.38  19.15  58643   135     NaN
# 1  11.7  20.39  18.62  57857   157     NaN
# 2  57.2  20.67  18.75  59498    90       k
# 3  31.8  21.99  19.91  58948   150     NaN
# 4  56.0  19.54  17.58  59605    64     k+a
# 5  18.2  20.46  18.35  55782    74       k
# 6  55.2  21.37  19.00  57965    96     NaN
# 7  19.8  20.02  18.05  76163    67     NaN
# 8  27.7  20.22  18.18  58182    67     NaN

# %%
df = table.to_pandas()

rows, columns = df.shape

extended_col_info =[]
for i in range(columns):
    column_info = []

    column_header = df.columns[i] # Get the header of each column
    column_info.append(column_header) 

    column_type = df[column_header].dtype
    if pd.api.types.is_float_dtype(column_type) == True or pd.api.types.is_integer_dtype(column_type) == True:
        column_info.append("N")  # Numeric column
    elif pd.api.types.is_string_dtype(column_type) == True:
        column_info.append("S")  # String column
        
    column_info.append(i)  # Column name/index
    column_info.append(rows)  # Number of rows
    extended_col_info.append(column_info)

pprint(extended_col_info)
# Out:
# [['[BBG2007b]', 'N', 0, 115],
#  ['n_[BBG2007b]', 'S', 1, 115],
#  ['Name', 'S', 2, 115],
#  ['RAh', 'N', 3, 115],
#  ['RAm', 'N', 4, 115],
#  ['RAs', 'N', 5, 115],
#  ['DE-', 'S', 6, 115],
#  ['DEd', 'N', 7, 115],
#  ['DEm', 'N', 8, 115],
#  ['DEs', 'N', 9, 115],
#  ['Bmag', 'N', 10, 115],
#  ['Rmag', 'N', 11, 115],
#  ['RV', 'N', 12, 115],
#  ['e_RV', 'N', 13, 115],
#  ['SpClass', 'S', 14, 115]]

# %%
magic_master_dict, magic_cleaned_dict = get_magic_numbers_main(df, extended_col_info, sign_violation_theshold = 3,gauss_threshold = 0.01, overlap_threshold=5.0, plot_graphs = False)
# Out:
#   Skipping Processes 2 and 3 due to identical numeric values.
#   Skipping Processes 2 and 3 due to identical numeric values.

# %%
pprint ("Cleaned Magic Numbers:")
pprint(magic_cleaned_dict)
# Note: that the non numeric columns are ignored in the magic number detection 
# and in the cleaned results are last with None indicating it.
# Out:
# 'Cleaned Magic Numbers:'
# {'Bmag': [],
#  'DE-': [],
#  'DEm': [],
#  'DEs': [0.2],
#  'Name': [],
#  'RAm': [],
#  'RAs': [],
#  'RV': [],
#  'Rmag': [],
#  'SpClass': [],
#  '[BBG2007b]': [],
#  'e_RV': [],
#  'n_[BBG2007b]': []}

# %%
from astropy.io import ascii

# Local data file
data_file = "gxfluxes.dat"

# ReadMe URL for the data
readme_url = "ReadMe_531.txt"

# Read the table using CDS format
table = ascii.read(data_file, readme=readme_url, format="cds")

# Convert to pandas DataFrame
df = table.to_pandas()

# 1. Force all rows to show
pd.set_option('display.max_rows', None)

# 2. Force all columns to show (since you have 31 columns)
pd.set_option('display.max_columns', None)

# 3. Prevent the text from "wrapping" to a new line
pd.set_option('display.width', None)

print(df)
# Out:
# WARNING: UnitsWarning: '[10-7W]' did not parse as cds unit: Syntax error parsing unit '[10-7W]' If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARN
# 441   N7682  NaN   23   26   30   +    3   15   30     I   9153  14.10     2
# 442   N7714  NaN   23   33   40   +    1   52   42     I   4043  13.00     3
# 443   N7769  NaN   23   48   31   +   19   52   17     I   6367  12.44     4
# 444   N7771  NaN   23   48   52   +   19   50    0     I   6367  12.51     1
# 445   N7793  NaN   23   55   15   -   32   52    5     I   2146   9.25     7
# 446     SMC    a    0   51    0   -   73    6    0   NaN      0   2.48     9
# 447   U3691  NaN    7    5    6   +   15   15    0     I   5156  13.30     6
#
#      RA_Xh  RA_Xm  RA_Xs DE_X-  DE_Xd  DE_Xm  DE_Xs  radius l_counts  \
# 0        3     41     35     +     67     56     19     510      NaN
# 1     <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 2     <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 3     <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 4     <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 5       22     54     23     -     36     43     57     240      NaN
# 6        1      2     28     +      1     46     15     300      NaN
# 7     <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 8     <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 9       10     25      1     +     68     43     37      90      NaN
# 10      12     32     24     +     15     50     47     180      NaN
# 11    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 12    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 13      13     33     45     -     33     42     16     360      NaN
# 14    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 15      13     46     28     -     30      3     44      90      NaN
# 16    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 17    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 18    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>      NaN
# 19    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 20    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 21    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 22    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 23    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 24    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>      NaN
# 25    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>      NaN
# 26       0     44     28     -     21      1     59     600      NaN
# 27       0     45      6     -     25     33     48     180      NaN
# 28       0     45      6     -     25     33     43     660      NaN
# 29    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 30       0     55      6     +     30      4     57      60      NaN
# 31       0     55      5     +     30      4     48    <NA>      NaN
# 32    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 33       1     20     24     +     33     12      2     210      NaN
# 34       1     20     51     +     32     59     38     630      NaN
# 35    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 36    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 37    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 38       1     22     10     +      9     16     29     240      NaN
# 39       1     22     56     +      1     29     59     270      NaN
# 40    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 41    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 42    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 43    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>      NaN
# 44    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>      NaN
# 45    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 46    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 47       1     34      3     +     15     31     57     300      NaN
# 48    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 49       1     50     34     -     13     58     52     480      NaN
# 50    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 51    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 52       2     15     13     +     14     18      3     120      NaN
# 53       2     25     10     -      1     22      8    <NA>      NaN
# 54    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 55    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 56    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 57       2     32     11     -      9      0     26     130      NaN
# 58       2     32     11     -      9      0     19     450      NaN
# 59       2     37     58     -      8     37     33     240      NaN
# 60    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 61       2     38     37     -      8     28      1     240      NaN
# 62       2     40      7     -      0     13     27     360      NaN
# 63       2     41      4     +      1      8     59     210      NaN
# 64    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 65    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 66       2     44      9     -     30     29      4     210      NaN
# 67    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 68    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 69    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 70       3      5     49     +      3     55      0     210      NaN
# 71    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 72       3     17     25     -     19     35      0     120      NaN
# 73       3     17     42     -     66     40     12     180      NaN
# 74       3     20     47     -     37     22     53    <NA>      NaN
# 75       3     20     47     -     37     23      7     120      NaN
# 76    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 77    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 78       3     24      4     -     21     30     28     360      NaN
# 79    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 80       3     31     12     -      5     15     30    <NA>      NaN
# 81       3     31     44     -     36     18     17    <NA>      NaN
# 82       3     34     30     -     35      8     20     210      NaN
# 83       3     34     48     -     36      9     43     180      NaN
# 84       3     35      3     -     35     40     47    <NA>      NaN
# 85    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 86       3     36     20     -     23     11     14     480      NaN
# 87       3     36     46     -     26     29     49    <NA>      NaN
# 88       3     36     35     -     35     36     56    1200      NaN
# 89    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 90       3     36     56     -     35     45     18     300      NaN
# 91       3     37     55     -     18     44      9     300      NaN
# 92       3     40      7     -     13     40     59     270      NaN
# 93    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 94    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 95    <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 96       4      8     45     -     56     14     38     240      NaN
# 97       4     15      8     -     55     54     43     270      NaN
# 98       4     16     59     -     62     54      3     180      NaN
# 99       4     18     53     -     55      3     21     110      NaN
# 100      4     18     54     -     55      3     14     300      NaN
# 101   <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 102      4     26      5     +     64     44     32     210      NaN
# 103   <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 104      4     29     17     -      5     11     56     300      NaN
# 105      4     31     35     -      8     40     53     180      NaN
# 106   <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 107      4     44     55     -     59     19     59     210      NaN
# 108   <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 109   <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 110      5     36     39     +     69     20     59     180      NaN
# 111   <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 112      7     15     37     +     85     48     40     240      NaN
# 113   <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 114   <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 115      7     31     37     +     65     42     20     100      NaN
# 116      7     32      8     +     65     42     44     390      NaN
# 117   <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 118   <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 119   <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 120   <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 121      8     17     42     +     21     13     57     360      NaN
# 122      8     32     16     +     28     39     10     120      NaN
# 123   <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 124   <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 125   <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 126   <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 127   <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 128   <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 129   <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 130   <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 131      9      7      5     +      7     22     59    <NA>      NaN
# 132      9      7     40     +      7     14     30    <NA>      NaN
# 133   <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 134   <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 135      9     16     44     +     33     57     31     360      NaN
# 136      9     15     35     -     22      8      0     150      NaN
# 137      9     18     36     +     51     11     35     180      NaN
# 138   <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 139   <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 140      9     29     20     +     21     43     31     210      NaN
# 141   <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 142   <NA>   <NA>   <NA>   NaN   <NA>   <NA>   <NA>    <NA>        <
# 143      9     40      3     -      3     28     26     240      NaN
# 144      9     43     18     -     14      5     53    <NA>      NaN
# 145      9     43     18     -     14      5     41    <NA>      NaN
# ...
# 318    353.72      29.3     NaN    36.94     NaN    12.95   27.000     NaN
# 319     28.72       6.9     NaN     6.92     NaN     2.35   41.300     NaN
# 320     45.04       NaN       <     3.76       <     1.20   74.600       <
# 321     96.74       NaN       <     5.72       <     7.58   27.000       <
# 322    584.30      47.3     NaN    34.52     NaN    29.66   27.000     NaN
# 323   1064.24      41.4     NaN   172.75     NaN    46.98   27.000     NaN
# 324     38.03       NaN       <     9.97       <     3.43   27.000       <
# 325     86.34       NaN       <     9.02       <     3.16   27.000       <
# 326    110.41       NaN       <     9.07       <     3.10   28.800       <
# 327    108.52      12.8     NaN    25.25     NaN     8.77   27.000     NaN
# 328    176.39      23.9     NaN    20.89     NaN     5.58   37.400     NaN
# 329     72.53      17.0     NaN     7.05     NaN     2.38   27.000     NaN
# 330     33.71       7.9     NaN    18.32     NaN    20.42    6.900     NaN
# 331     79.03      17.3     NaN     6.54     NaN     1.71   24.300     NaN
# 332     70.26       NaN       <     5.74       <     1.54   27.000       <
# 333    235.82      22.2     NaN    42.79     NaN    12.16   88.400     NaN
# 334    172.52      26.5     NaN    14.09     NaN     3.79   27.000     NaN
# 335     34.57       7.6     NaN    24.31     NaN     6.89   84.700     NaN
# 336    106.93      16.5     NaN    21.97     NaN     7.89    6.600     NaN
# 428   5632.75      82.7     NaN   382.14     NaN   629.20   97.000     NaN
# 429     30.96       NaN       <    12.95       <     4.45   32.300       <
# 430     94.95      13.8     NaN    25.60     NaN     8.74   31.300     NaN
# 431     41.13       NaN       <    12.16       <     3.69   72.000       <
# 432    434.04      32.5     NaN    32.39     NaN    11.09   28.300     NaN
# 433    126.71      21.0     NaN     8.28     NaN     2.83   27.800     NaN
# 434     92.52      20.5     NaN     6.05     NaN     2.07   32.500     NaN
# 435     84.28       NaN       <     9.62       <     3.85   65.100       <
# 436    440.37      33.1     NaN    50.29     NaN    14.92   75.000     NaN
# 437    167.44      24.8     NaN    19.12     NaN     5.67   68.300     NaN
# 438     32.05       9.1     NaN     7.12     NaN     2.78   69.600     NaN
# 439     42.41       NaN       <     9.43       <     3.68   72.600       <
# 440     23.97       7.1     NaN    26.93     NaN    10.72  101.700     NaN
# 441     26.42       NaN       <    29.68       <    11.82  101.500       <
# 442     18.50       5.4     NaN     7.08     NaN     2.82   59.300     NaN
# 443     44.68       NaN       <     7.92       <     3.09   84.600       <
# 444    104.74      14.9     NaN    18.56     NaN     7.24   85.700     NaN
# 445     39.55       7.7     NaN    21.38     NaN     6.81    2.800     NaN
# 446       NaN       NaN     NaN      NaN     NaN      NaN    0.063     NaN
# 447     91.08       NaN       <     7.69       <     3.48   46.000       <
#
#      logLx
# 0    40.37
# 1    40.21
# 2    40.22
# 3    41.85
# 4    40.66
# 5    41.01
# 6    38.11
# 7    39.12
# 8    39.42
# 9    38.50
# 10   43.40
# 11   41.22
# 12   40.10
# 13   41.98
# 14   42.13
# 15   43.77
# 16   41.65
# 17   41.43
# 18   38.82
# 19   41.75
# 20   41.51
# 21   41.53
# 22   41.62
# 23   38.02
# 24   37.73
# 25   39.56
# 26   38.86
# 27   39.58
# 28   39.87
# 29   41.61
# 30   41.66
# 31   42.06
# 32   41.74
# 33   42.45
# 34   43.04
# 35   40.86
# 36   41.70
# 37   41.45
# 38   41.35
# 39   42.64
# 40   40.61
# 41   40.69
# 42   40.63
# 43   38.98
# 44   39.09
# 45   39.13
# 46   40.78
# 47   39.99
# 48   39.57
# 49   41.34
# 50   41.30
# 51   41.21
# 52   41.22
# 53   40.59
# 54   41.28
# 55   41.15
# 56   41.62
# 57   44.46
# 58   44.19
# 59   40.70
# 60   41.40
# 61   40.71
# 62   42.12
# 63   40.43
# 64   40.90
# 65   41.21
# 66   41.29
# 67   41.56
# 68   40.22
# 69   40.86
# 70   42.95
# 71   41.40
# 72   40.26
# 73   39.90
# 74   41.25
# 75   41.01
# 76   40.74
# 77   40.37
# 78   40.81
# 79   40.63
# 80   40.99
# 81   41.18
# 82   40.78
# 83   40.72
# 84   40.76
# 85   40.36
# 86   41.14
# 87   40.46
# 88   42.31
# 89   39.58
# 90   41.47
# 91   41.31
# 92   41.11
# 93   41.57
# 94   40.14
# 95   40.02
# 96   40.18
# 97   40.90
# 98   40.79
# 99   42.08
# 100  41.66
# 290  41.72
# 291  40.73
# 292  40.14
# 293  40.49
# 294  40.39
# 295  40.51
# 296  40.63
# 297  40.20
# 298  40.38
# 299  40.92
# 300  41.08
# 301  40.19
# 302  40.36
# 303  40.61
# 304  40.72
# 305  40.47
# 306  40.38
# 307  41.62
# 308  41.84
# 309  40.66
# 310  41.56
# 311  41.17
# 312  40.43
# 313  40.41
# 314  40.31
# 315  41.65
# 316  41.99
# 317  40.22
# 318  41.05
# 319  40.68
# 320  40.90
# 321  40.82
# 322  41.41
# 323  41.61
# 324  40.48
# 325  40.44
# 326  40.49
# 327  40.88
# 328  40.97
# 329  40.32
# 330  40.07
# 331  40.08
# 332  40.13
# 333  42.06
# 334  40.52
# 335  41.77
# 336  39.61
# 337  40.28
# 338  40.86
# 339  40.32
# 340  41.92
# 341  41.25
# 342  43.17
# 343  39.95
# 344  41.07
# 345  41.06
# 346  41.21
# 347  40.61
# 348  41.14
# 349  39.11
# 350  40.77
# 351  41.48
# 352  41.47
# 353  40.80
# 354  39.79
# 355  39.83
# 356  40.51
# 357  40.55
# 358  40.70
# 359  39.19
# 360  38.83
# 361  40.97
# 362  41.37
# 363  41.04
# 364  40.95
# 365  41.50
# 366  41.16
# 367  41.10
# 368  41.41
# 369  41.33
# 370  40.79
# 371  41.18
# 372  41.50
# 373    NaN
# 374  40.24
# 375  39.28
# 376  39.43
# 377  41.08
# 378  42.45
# 379  41.93
# 380  43.83
# 381  43.72
# 382  40.79
# 383  40.76
# 384  39.68
# 385  40.97
# 386  40.92
# 387  41.88
# 388  43.55
# 389  41.14
# 390  41.48
# 391  40.55
# 392  42.11
# 393  40.36
# 394  40.17
# 395  40.53
# 396  40.31
# 397  41.47
# 398  41.61
# 399  41.71
# 400  42.46
# 401  42.09
# 402  42.27
# 403  40.51
# 404  42.67
# 405  39.80
# 406  40.38
# 407  41.92
# 408  41.65
# 409  37.70
# 410  41.93
# 411  41.78
# 412  41.36
# 413  41.09
# 414  40.47
# 415  41.02
# 416  41.43
# 417  41.25
# 418  41.13
# 419  43.15
# 420  41.89
# 421  42.02
# 422  41.04
# 423  40.71
# 424  40.75
# 425  40.51
# 426  40.89
# 427  43.64
# 428  43.85
# 429  40.74
# 430  41.01
# 431  41.36
# 432  41.03
# 433  40.42
# 434  40.42
# 435  41.29
# 436  42.00
# 437  41.50
# 438  41.21
# 439  41.37
# 440  42.12
# 441  42.16
# 442  41.07
# 443  41.42
# 444  41.80
# 445  38.81
# 446  37.79
# 447  40.95

# %%
df = table.to_pandas()

rows, columns = df.shape

extended_col_info =[]
for i in range(columns):
    column_info = []

    column_header = df.columns[i] # Get the header of each column
    column_info.append(column_header) 

    column_type = df[column_header].dtype
    if pd.api.types.is_float_dtype(column_type) == True or pd.api.types.is_integer_dtype(column_type) == True:
        column_info.append("N")  # Numeric column
    elif pd.api.types.is_string_dtype(column_type) == True:
        column_info.append("S")  # String column
        
    column_info.append(i)  # Column name/index
    column_info.append(rows)  # Number of rows
    extended_col_info.append(column_info)

pprint(extended_col_info)
# Out:
# [['Name', 'S', 0, 448],
#  ['note', 'S', 1, 448],
#  ['RAh', 'N', 2, 448],
#  ['RAm', 'N', 3, 448],
#  ['RAs', 'N', 4, 448],
#  ['DE-', 'S', 5, 448],
#  ['DEd', 'N', 6, 448],
#  ['DEm', 'N', 7, 448],
#  ['DEs', 'N', 8, 448],
#  ['instr', 'S', 9, 448],
#  ['AA', 'N', 10, 448],
#  ['Bmag', 'N', 11, 448],
#  ['type', 'N', 12, 448],
#  ['RA_Xh', 'N', 13, 448],
#  ['RA_Xm', 'N', 14, 448],
#  ['RA_Xs', 'N', 15, 448],
#  ['DE_X-', 'S', 16, 448],
#  ['DE_Xd', 'N', 17, 448],
#  ['DE_Xm', 'N', 18, 448],
#  ['DE_Xs', 'N', 19, 448],
#  ['radius', 'N', 20, 448],
#  ['l_counts', 'S', 21, 448],
#  ['counts', 'N', 22, 448],
#  ['e_counts', 'N', 23, 448],
#  ['l_crate', 'S', 24, 448],
#  ['crate', 'N', 25, 448],
#  ['l_FluxX', 'S', 26, 448],
#  ['FluxX', 'N', 27, 448],
#  ['dist', 'N', 28, 448],
#  ['l_logLx', 'S', 29, 448],
#  ['logLx', 'N', 30, 448]]

# %%
magic_master_dict, magic_cleaned_dict = get_magic_numbers_main(df, extended_col_info, sign_violation_theshold = 3,gauss_threshold = 0.01, overlap_threshold=10.0, plot_graphs = False)

# %%
pprint ("Cleaned Magic Numbers:")
pprint(magic_cleaned_dict)
# Note: that the non numeric columns are ignored in the magic number detection 
# and in the cleaned results are last with None indicating it.
print ("Detected Magic Numbers:")
pprint(magic_master_dict)
# Out:
# 'Cleaned Magic Numbers:'
# {'AA': [99999.0],
#  'Bmag': [],
#  'DE-': [],
#  'DE_X-': [],
#  'DE_Xd': [],
#  'DE_Xm': [],
#  'DE_Xs': [],
#  'DEd': [85.0],
#  'DEm': [],
#  'DEs': [],
#  'FluxX': [],
#  'Name': [],
#  'RA_Xh': [],
#  'RA_Xm': [],
#  'RA_Xs': [],
#  'RAh': [],
#  'RAm': [],
#  'RAs': [],
#  'counts': [],
#  'crate': [],
#  'dist': [],
#  'e_counts': [],
#  'instr': [],
#  'l_FluxX': [],
#  'l_counts': [],
#  'l_crate': [],
#  'l_logLx': [],
#  'logLx': [],
#  'note': [],
#  'radius': [],
#  'type': []}
# Detected Magic Numbers:
# {'AA': {'all_magic_numbers': None,
#         'magic_distanced_numbers': array([99999.]),
#         'magic_sign_violation': [],
#         'magic_strings': []},
#  'Bmag': {'all_magic_numbers': None,
#           'magic_distanced_numbers': array([], dtype=float64),
#           'magic_sign_violation': [],
#           'magic_strings': []},
#  'DE-': {'all_magic_numbers': None,
#          'magic_distanced_numbers': [],
#          'magic_sign_violation': [],
#          'magic_strings': []},
#  'DE_X-': {'all_magic_numbers': None,
#            'magic_distanced_numbers': [],
#            'magic_sign_violation': [],
#            'magic_strings': []},
#  'DE_Xd': {'all_magic_numbers': None,
#            'magic_distanced_numbers': array([], dtype=float64),
#            'magic_sign_violation': [],
#            'magic_strings': []},
#  'DE_Xm': {'all_magic_numbers': None,
#            'magic_distanced_numbers': array([], dtype=float64),
#            'magic_sign_violation': [],
#            'magic_strings': []},
#  'DE_Xs': {'all_magic_numbers': None,
#            'magic_distanced_numbers': array([], dtype=float64),
#            'magic_sign_violation': [],
#            'magic_strings': []},
#  'DEd': {'all_magic_numbers': None,
#          'magic_distanced_numbers': array([85.]),
#          'magic_sign_violation': [],
#          'magic_strings': []},
#  'DEm': {'all_magic_numbers': None,
#          'magic_distanced_numbers': array([], dtype=float64),
#          'magic_sign_violation': [],
#          'magic_strings': []},
#  'DEs': {'all_magic_numbers': None,
#          'magic_distanced_numbers': array([], dtype=float64),
#          'magic_sign_violation': [],
#          'magic_strings': []},
#  'FluxX': {'all_magic_numbers': None,
#            'magic_distanced_numbers': array([], dtype=float64),
#            'magic_sign_violation': [],
#            'magic_strings': []},
#  'Name': {'all_magic_numbers': None,
#           'magic_distanced_numbers': [],
#           'magic_sign_violation': [],
#           'magic_strings': []},
#  'RA_Xh': {'all_magic_numbers': None,
#            'magic_distanced_numbers': array([], dtype=float64),
#            'magic_sign_violation': [],
#            'magic_strings': []},
#  'RA_Xm': {'all_magic_numbers': None,
#            'magic_distanced_numbers': array([], dtype=float64),
#            'magic_sign_violation': [],
#            'magic_strings': []},
#  'RA_Xs': {'all_magic_numbers': None,
#            'magic_distanced_numbers': array([], dtype=float64),
#            'magic_sign_violation': [],
#            'magic_strings': []},
#  'RAh': {'all_magic_numbers': None,
#          'magic_distanced_numbers': array([], dtype=float64),
#          'magic_sign_violation': [],
#          'magic_strings': []},
#  'RAm': {'all_magic_numbers': None,
#          'magic_distanced_numbers': array([], dtype=float64),
#          'magic_sign_violation': [],
#          'magic_strings': []},
#  'RAs': {'all_magic_numbers': None,
#          'magic_distanced_numbers': array([], dtype=float64),
#          'magic_sign_violation': [],
#          'magic_strings': []},
#  'counts': {'all_magic_numbers': None,
#             'magic_distanced_numbers': array([], dtype=float64),
#             'magic_sign_violation': [],
#             'magic_strings': []},
#  'crate': {'all_magic_numbers': None,
#            'magic_distanced_numbers': array([], dtype=float64),
#            'magic_sign_violation': [],
#            'magic_strings': []},
#  'dist': {'all_magic_numbers': None,
#           'magic_distanced_numbers': array([], dtype=float64),
#           'magic_sign_violation': [],
#           'magic_strings': []},
#  'e_counts': {'all_magic_numbers': None,
#               'magic_distanced_numbers': array([], dtype=float64),
#               'magic_sign_violation': [],
#               'magic_strings': []},
#  'instr': {'all_magic_numbers': None,
#            'magic_distanced_numbers': [],
#            'magic_sign_violation': [],
#            'magic_strings': []},
#  'l_FluxX': {'all_magic_numbers': None,
#              'magic_distanced_numbers': [],
#              'magic_sign_violation': [],
#              'magic_strings': []},
#  'l_counts': {'all_magic_numbers': None,
#               'magic_distanced_numbers': [],
#               'magic_sign_violation': [],
#               'magic_strings': []},
#  'l_crate': {'all_magic_numbers': None,
#              'magic_distanced_numbers': [],
#              'magic_sign_violation': [],
#              'magic_strings': []},
#  'l_logLx': {'all_magic_numbers': None,
#              'magic_distanced_numbers': [],
#              'magic_sign_violation': [],
#              'magic_strings': []},
#  'logLx': {'all_magic_numbers': None,
#            'magic_distanced_numbers': array([], dtype=float64),
#            'magic_sign_violation': [],
#            'magic_strings': []},
#  'note': {'all_magic_numbers': None,
#           'magic_distanced_numbers': [],
#           'magic_sign_violation': [],
#           'magic_strings': []},
#  'radius': {'all_magic_numbers': None,
#             'magic_distanced_numbers': array([], dtype=float64),
#             'magic_sign_violation': [],
#             'magic_strings': []},
#  'type': {'all_magic_numbers': None,
#           'magic_distanced_numbers': array([], dtype=float64),
#           'magic_sign_violation': [],
#           'magic_strings': []}}

# %%
from astropy.io import ascii

readme_url = "ReadMe_table2.txt"
data_url = "https://cdsarc.cds.unistra.fr/ftp/J/ApJS/243/3/table2.dat"

table = ascii.read(data_url, readme=readme_url, format="cds")
df = table.to_pandas()
print(df[:9])

df = table.to_pandas()

rows, columns = df.shape

extended_col_info =[]
for i in range(columns):
    column_info = []

    column_header = df.columns[i] # Get the header of each column
    column_info.append(column_header) 

    column_type = df[column_header].dtype
    if pd.api.types.is_float_dtype(column_type) == True or pd.api.types.is_integer_dtype(column_type) == True:
        column_info.append("N")  # Numeric column
    elif pd.api.types.is_string_dtype(column_type) == True:
        column_info.append("S")  # String column
        
    column_info.append(i)  # Column name/index
    column_info.append(rows)  # Number of rows
    extended_col_info.append(column_info)

pprint(extended_col_info)
# Out:
# WARNING: UnitsWarning: '"datime"' did not parse as cds unit: Invalid character at col 0 If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING:astropy:UnitsWarning: '"datime"' did not parse as cds unit: Invalid character at col 0 If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
# WARNING: UnitsWarning: '"datime"' did not parse as cds unit: Invalid character at col 0 If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING:astropy:UnitsWarning: '"datime"' did not parse as cds unit: Invalid character at col 0 If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
#        Gal  ---  NGC  ObsID f_ObsID      RAdeg      DEdeg  \
# 0  NGC0337  NGC  337  12979       d  14.955369  -7.574487
# 1  NGC0584  NGC  584  12175       d  22.834923  -6.860680
# 2  NGC0628  NGC  628  14801     NaN  24.197530  15.759051
# 3  NGC0628  NGC  628  16000     NaN  24.197354  15.758780
# 4  NGC0628  NGC  628  16001     NaN  24.197460  15.758214
# 5  NGC0628  NGC  628  16002     NaN  24.203547  15.757404
# 6  NGC0628  NGC  628  16003     NaN  24.203701  15.757877
# 7  NGC0628  NGC  628  16484     NaN  24.197419  15.758157
# 8  NGC0628  NGC  628  16485     NaN  24.197464  15.758179
#
#                ObsDate  Exp   Nfl  Tfl   dRA   dDE Mode
# 0  2011-07-19T23:07:02   10  <NA>  NaN   NaN   NaN    F
# 1  2010-09-07T01:40:53   10  <NA>  NaN   NaN   NaN    V
# 2  2013-08-21T15:40:51   10  <NA>  NaN  0.05  0.01    V
# 3  2013-09-21T06:40:27   40  <NA>  NaN  0.56 -0.24    V
# 4  2013-10-07T23:56:17   15  <NA>  NaN  0.24 -0.07    V
# 5  2013-11-14T20:10:48   38  <NA>  NaN  0.08  0.16    V
# 6  2013-12-15T15:55:42   40  <NA>  NaN  0.04 -0.11    V
# 7  2013-10-10T14:31:23   15  <NA>  NaN  0.45  0.14    V
# 8  2013-10-11T11:13:35    9  <NA>  NaN  0.32  0.06    V
# [['Gal', 'S', 0, 200],
#  ['---', 'S', 1, 200],
#  ['NGC', 'N', 2, 200],
#  ['ObsID', 'N', 3, 200],
#  ['f_ObsID', 'S', 4, 200],
#  ['RAdeg', 'N', 5, 200],
#  ['DEdeg', 'N', 6, 200],
#  ['ObsDate', 'S', 7, 200],
#  ['Exp', 'N', 8, 200],
#  ['Nfl', 'N', 9, 200],
#  ['Tfl', 'N', 10, 200],
#  ['dRA', 'N', 11, 200],
#  ['dDE', 'N', 12, 200],
#  ['Mode', 'S', 13, 200]]

# %%
magic_master_dict, magic_cleaned_dict = get_magic_numbers_main(df, extended_col_info, sign_violation_theshold = 3,gauss_threshold = 0.01, overlap_threshold=10.0, plot_graphs = False)
print ("Detected Magic Numbers:")
pprint(magic_cleaned_dict)
# Note: that the non numeric columns are ignored in the magic number detection 
# and in the cleaned results are last with None indicating it.
# Out:
# Detected Magic Numbers:
# {'---': [],
#  'DEdeg': [],
#  'Exp': [],
#  'Gal': [],
#  'Mode': [],
#  'NGC': [6946.0, 7331.0, 7552.0],
#  'Nfl': [],
#  'ObsDate': [],
#  'ObsID': [],
#  'RAdeg': [],
#  'Tfl': [],
#  'dDE': [],
#  'dRA': [],
#  'f_ObsID': []}

# %%
from astropy.io import ascii

readme_url = "ReadMe_table7.txt"
data_url = "https://cdsarc.cds.unistra.fr/ftp/J/ApJS/243/3/table7.dat"

table = ascii.read(data_url, readme=readme_url, format="cds")
df = table.to_pandas()
print(df[:9])

df = table.to_pandas()

rows, columns = df.shape

extended_col_info =[]
for i in range(columns):
    column_info = []

    column_header = df.columns[i] # Get the header of each column
    column_info.append(column_header) 

    column_type = df[column_header].dtype
    if pd.api.types.is_float_dtype(column_type) == True or pd.api.types.is_integer_dtype(column_type) == True:
        column_info.append("N")  # Numeric column
    elif pd.api.types.is_string_dtype(column_type) == True:
        column_info.append("S")  # String column
        
    column_info.append(i)  # Column name/index
    column_info.append(rows)  # Number of rows
    extended_col_info.append(column_info)

pprint(extended_col_info)
# Out:
# WARNING: UnitsWarning: '[10-7W]' did not parse as cds unit: Syntax error parsing unit '[10-7W]' If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING:astropy:UnitsWarning: '[10-7W]' did not parse as cds unit: Syntax error parsing unit '[10-7W]' If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
# WARNING: UnitsWarning: '[10-7W]' did not parse as cds unit: Syntax error parsing unit '[10-7W]' If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING:astropy:UnitsWarning: '[10-7W]' did not parse as cds unit: Syntax error parsing unit '[10-7W]' If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
#    ---  NGC  ID      RAdeg     DEdeg  theta    NFB  e_NFB     NH   e_NH  \
# 0  NGC  337   1  14.931379 -7.583701    1.7    7.8    4.2  0.056  0.056
# 1  NGC  337   2  14.947916 -7.571299    0.8   41.0    7.9  0.109  0.154
# 2  NGC  337   3  14.952117 -7.582421    0.5   65.3    9.7  0.314  0.381
# 3  NGC  337   4  14.956155 -7.576573    0.2  106.8   12.1  0.308  0.326
# 4  NGC  337   5  14.956202 -7.589868    0.7   22.3    6.2  0.779  0.410
# 5  NGC  337   6  14.960001 -7.579352    0.1    4.7    2.2  0.056  0.056
# 6  NGC  337   7  14.960013 -7.581717    0.2   42.8    8.1  0.647  0.796
# 7  NGC  337   8  14.960671 -7.582800    0.3  300.5   19.5  0.136  0.155
# 8  NGC  337   9  14.966231 -7.582696    0.5   14.4    5.2  0.056  0.056
#
#    Gamma  e_Gamma  logFFB  logLFB  Loc
# 0   1.70     1.70   -14.1    38.6    4
# 1   3.06    -1.00   -13.7    39.1    5
# 2   1.98     0.74   -13.2    39.5    1
# 3   1.60     0.53   -13.0    39.8    1
# 4   3.06    -1.00   -13.8    38.9    5
# 5   1.70     1.70   -14.3    38.5    1
# 6   1.57     0.90   -13.3    39.5    1
# 7   1.40     0.29   -12.5    40.3    1
# 8   1.70     1.70   -13.8    39.0    1
# [['---', 'S', 0, 4442],
#  ['NGC', 'N', 1, 4442],
#  ['ID', 'N', 2, 4442],
#  ['RAdeg', 'N', 3, 4442],
#  ['DEdeg', 'N', 4, 4442],
#  ['theta', 'N', 5, 4442],
#  ['NFB', 'N', 6, 4442],
#  ['e_NFB', 'N', 7, 4442],
#  ['NH', 'N', 8, 4442],
#  ['e_NH', 'N', 9, 4442],
#  ['Gamma', 'N', 10, 4442],
#  ['e_Gamma', 'N', 11, 4442],
#  ['logFFB', 'N', 12, 4442],
#  ['logLFB', 'N', 13, 4442],
#  ['Loc', 'N', 14, 4442]]

# %%
magic_master_dict, magic_cleaned_dict = get_magic_numbers_main(df, extended_col_info, sign_violation_theshold = 3,gauss_threshold = 0.01, overlap_threshold=10.0, plot_graphs = False)
print ("Detected Magic Numbers:")
pprint(magic_cleaned_dict)
# Note: that the non numeric columns are ignored in the magic number detection 
# and in the cleaned results are last with None indicating it.
# Out:
# Detected Magic Numbers:
# {'---': [],
#  'DEdeg': [],
#  'Gamma': [3.3],
#  'ID': [],
#  'Loc': [],
#  'NFB': [],
#  'NGC': [337.0,
#          584.0,
#          628.0,
#          925.0,
#          1097.0,
#          1291.0,
#          1316.0,
#          1404.0,
#          6946.0,
#          7331.0,
#          7552.0],
#  'NH': [],
#  'RAdeg': [],
#  'e_Gamma': [-1.0],
#  'e_NFB': [],
#  'e_NH': [-1.0],
#  'logFFB': [],
#  'logLFB': [],
#  'theta': []}

# %%
def synthetic_data(
        mean, 
        sigma, 
        num_samples=1000, 
        random_seed=None, 
        magic_values=[-999, 999],
        quantities=[100, 50], 
        col_names="synthetic_col"):

    if random_seed is not None:
        np.random.seed(random_seed)

    # --- 1. Calculate Clipping Bounds (HARDCODED 3-SIGMA) ---
    # We hardcode the sigma_limit to 3.0 to maintain the 99.7% geometry.
    SIGMA_LIMIT = 3.0  
    lower_bound = mean - SIGMA_LIMIT * sigma
    upper_bound = mean + SIGMA_LIMIT * sigma
    
    # --- 2. Generate and Clip the Main Normal Distribution Samples ---
    
    # Generate the initial samples
    synthetic_col = np.random.normal(mean, sigma, num_samples)
    
    # Apply 3-sigma clipping to ensure the normal data is within the 99.7% range
    synthetic_col = np.clip(synthetic_col, a_min=lower_bound, a_max=upper_bound)

    # --- 3. Add Magic Values (Original behavior: total size increases) ---

    if len(magic_values) != len(quantities):
        raise ValueError("Length of magic_values must match length of quantities")
    
    # If no magic values, return just the normal distribution
    if len(magic_values) == 0:
        df = pd.DataFrame({col_names: synthetic_col})
        return df
    
    # Add magic values to the dataset
    for magic_value, quantity in zip(magic_values, quantities):
        magic_samples = np.full(quantity, magic_value)
        # This is where the array size increases:
        synthetic_col = np.concatenate((synthetic_col, magic_samples))
    
    # Shuffle the final array
    np.random.shuffle(synthetic_col)
    
    # Create DataFrame AFTER the loop
    df = pd.DataFrame({col_names: synthetic_col})
    return df

# Note: If you use the parameters quantities=[100, 50] and num_samples=1000,
# the final dataset will have 1000 + 100 + 50 = 1150 samples.

# %%
extended_col_info =[]
for i in range(columns):
    column_info = []

    column_header = df.columns[i] # Get the header of each column
    column_info.append(column_header) 

    column_type = df[column_header].dtype
    if pd.api.types.is_float_dtype(column_type) == True or pd.api.types.is_integer_dtype(column_type) == True:
        column_info.append("N")  # Numeric column
    elif pd.api.types.is_string_dtype(column_type) == True:
        column_info.append("S")  # String column
        
    column_info.append(i)  # Column name/index
    column_info.append(rows)  # Number of rows
    extended_col_info.append(column_info)

pprint(extended_col_info)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 extended_col_info =[]
# ----> 2 for i in range(columns):
#       3     column_info = []
#       5     column_header = df.columns[i] # Get the header of each column
#
# NameError: name 'columns' is not defined

# %%
import time

sample_data_values = np.linspace(100, 100000, num = 100)
total_time = []
data_samples = []

for sample in sample_data_values:
    sample = int(sample)
    start_time = time.time()
    df = synthetic_data(
        mean = 0, 
        sigma = 1, 
        num_samples=sample, 
        random_seed=None, 
        magic_values=[10, 9],
        quantities=[100, 50], 
        col_names="synthetic_col")
    
    extended_col_info =[]
    rows, columns = df.shape
    for i in range(columns):
        column_info = []

        column_header = df.columns[i] # Get the header of each column
        column_info.append(column_header) 

        column_type = df[column_header].dtype
        if pd.api.types.is_float_dtype(column_type) == True or pd.api.types.is_integer_dtype(column_type) == True:
            column_info.append("N")  # Numeric column
        elif pd.api.types.is_string_dtype(column_type) == True:
            column_info.append("S")  # String column
            
        column_info.append(i)  # Column name/index
        column_info.append(rows)  # Number of rows
        extended_col_info.append(column_info)
    
    magic_master_dict, magic_cleaned_dict = get_magic_numbers_main(df, extended_col_info, sign_violation_theshold = 3,gauss_threshold = 0.01, overlap_threshold=1.0, plot_graphs = False)

    end_time = time.time()
    total_time.append(end_time - start_time)
    data_samples.append(sample)

# %%
import matplotlib.pyplot as plt
import numpy as np  # Required for the math


# 1. Calculate the fit
# '1' means degree 1 (linear). It returns the slope (m) and intercept (b)
slope, intercept = np.polyfit(data_samples, total_time, 1)

# 2. Create the line of best fit
# We generate y values for the line using the equation: y = mx + b
fitted_line = [slope * x + intercept for x in data_samples]

# 3. Plotting
# Use scatter for actual data points to distinguish them from the line
plt.scatter(data_samples, total_time, color='blue', label='Actual Data')
plt.plot(data_samples, fitted_line, color='red', label=f'Fit: y={slope:.2f}x + {intercept:.2f}')

# 4. Labels and Legend
plt.title("Time Taken for Magic Number Detection vs. Data Samples")
plt.xlabel("Data Samples")
plt.ylabel("Time (ms)")
plt.legend() # Shows the labels defined above

plt.show()
